# %%
pip install torch
# Out:
# ...
#
# ...
#    ---------------------------------------- 0.0/204.1 MB ? eta -:--:--
#    ---------------------------------------- 0.6/204.1 MB 17.8 MB/s eta 0:00:12
#    ---------------------------------------- 1.9/204.1 MB 20.6 MB/s eta 0:00:10
#     --------------------------------------- 3.2/204.1 MB 25.8 MB/s eta 0:00:08
#     --------------------------------------- 4.7/204.1 MB 27.4 MB/s eta 0:00:08
#    - -------------------------------------- 6.4/204.1 MB 27.2 MB/s eta 0:00:08
#    - -------------------------------------- 8.1/204.1 MB 30.4 MB/s eta 0:00:07
#    - -------------------------------------- 9.6/204.1 MB 30.8 MB/s eta 0:00:07
#    -- ------------------------------------- 11.0/204.1 MB 32.7 MB/s eta 0:00:06
#    -- ------------------------------------- 12.5/204.1 MB 32.8 MB/s eta 0:00:06
#    -- ------------------------------------- 13.9/204.1 MB 32.8 MB/s eta 0:00:06
#    --- ------------------------------------ 15.4/204.1 MB 32.8 MB/s eta 0:00:06
# ...

# %%
component_choices = np.random.choice(8, size=2)
